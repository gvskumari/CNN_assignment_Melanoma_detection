# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %%
#Importing all the important libraries
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.
#
# Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
#Use 80% of the images for training, and 20% for validation.
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# **Visualize the data**
#
# Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# **Create the model**

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# **Compile the model**

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Train the model**

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 279s 1s/step - loss: 2.0537 - accuracy: 0.1869 - val_loss: 2.0253 - val_accuracy: 0.1924
# Epoch 2/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9931 - accuracy: 0.2517 - val_loss: 2.0143 - val_accuracy: 0.1879
# Epoch 3/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.8995 - accuracy: 0.2935 - val_loss: 1.7562 - val_accuracy: 0.3557
# Epoch 4/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.7697 - accuracy: 0.3337 - val_loss: 1.9460 - val_accuracy: 0.2752
# Epoch 5/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.7121 - accuracy: 0.3728 - val_loss: 1.5938 - val_accuracy: 0.4340
# Epoch 6/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.6308 - accuracy: 0.3979 - val_loss: 1.5700 - val_accuracy: 0.4027
# Epoch 7/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.5371 - accuracy: 0.4425 - val_loss: 1.5124 - val_accuracy: 0.4810
# Epoch 8/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.5121 - accuracy: 0.4593 - val_loss: 1.6321 - val_accuracy: 0.4430
# Epoch 9/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.4930 - accuracy: 0.4693 - val_loss: 1.4121 - val_accuracy: 0.5011
# Epoch 10/30
# 56/56 [==============================] - 4s 79ms/step - loss: 1.4563 - accuracy: 0.4877 - val_loss: 1.5381 - val_accuracy: 0.4273
# Epoch 11/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.4169 - accuracy: 0.4905 - val_loss: 1.4143 - val_accuracy: 0.5123
# Epoch 12/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.3399 - accuracy: 0.5273 - val_loss: 1.4732 - val_accuracy: 0.4586
# Epoch 13/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.2682 - accuracy: 0.5485 - val_loss: 1.5502 - val_accuracy: 0.4519
# Epoch 14/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.2210 - accuracy: 0.5686 - val_loss: 1.3957 - val_accuracy: 0.4989
# Epoch 15/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.1913 - accuracy: 0.5703 - val_loss: 1.4977 - val_accuracy: 0.5123
# Epoch 16/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.1687 - accuracy: 0.5776 - val_loss: 1.4493 - val_accuracy: 0.5213
# Epoch 17/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.0631 - accuracy: 0.6060 - val_loss: 1.5244 - val_accuracy: 0.4966
# Epoch 18/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.0541 - accuracy: 0.6144 - val_loss: 1.4801 - val_accuracy: 0.5123
# Epoch 19/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.9701 - accuracy: 0.6434 - val_loss: 1.5293 - val_accuracy: 0.4989
# Epoch 20/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.9684 - accuracy: 0.6429 - val_loss: 1.6560 - val_accuracy: 0.4877
# Epoch 21/30
# 56/56 [==============================] - 4s 77ms/step - loss: 0.9389 - accuracy: 0.6529 - val_loss: 1.7011 - val_accuracy: 0.4944
# Epoch 22/30
# 56/56 [==============================] - 4s 77ms/step - loss: 0.8371 - accuracy: 0.6959 - val_loss: 1.7379 - val_accuracy: 0.4586
# Epoch 23/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.7833 - accuracy: 0.7054 - val_loss: 1.8274 - val_accuracy: 0.5101
# Epoch 24/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.7612 - accuracy: 0.7098 - val_loss: 1.8964 - val_accuracy: 0.4989
# Epoch 25/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.6732 - accuracy: 0.7506 - val_loss: 2.1307 - val_accuracy: 0.4922
# Epoch 26/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.6763 - accuracy: 0.7612 - val_loss: 2.0474 - val_accuracy: 0.5011
# Epoch 27/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.6407 - accuracy: 0.7606 - val_loss: 2.0816 - val_accuracy: 0.4765
# Epoch 28/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.6802 - accuracy: 0.7467 - val_loss: 2.0863 - val_accuracy: 0.5011
# Epoch 29/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.5886 - accuracy: 0.7857 - val_loss: 2.2690 - val_accuracy: 0.4586
# Epoch 30/30
# 56/56 [==============================] - 4s 78ms/step - loss: 0.5095 - accuracy: 0.8131 - val_loss: 2.2936 - val_accuracy: 0.4653

# %% [markdown]
# **Visualizing training results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Finding on the first base model
#
# The model is overfitting because we can see difference in loss functions in training & test.

# %% [markdown]
# Visualize augmentation strategy works for one instance of training imag

# %%
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# **Create the model**

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# **Compiling the model**

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# **Training the model**

# %%
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 7s 94ms/step - loss: 2.1026 - accuracy: 0.1881 - val_loss: 2.0395 - val_accuracy: 0.1924
# Epoch 2/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0307 - accuracy: 0.2165 - val_loss: 2.0341 - val_accuracy: 0.2058
# Epoch 3/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0174 - accuracy: 0.2160 - val_loss: 2.0528 - val_accuracy: 0.2058
# Epoch 4/30
# 56/56 [==============================] - 5s 89ms/step - loss: 2.0303 - accuracy: 0.2031 - val_loss: 2.0459 - val_accuracy: 0.1499
# Epoch 5/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0188 - accuracy: 0.1998 - val_loss: 2.0231 - val_accuracy: 0.1969
# Epoch 6/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0115 - accuracy: 0.2165 - val_loss: 2.0141 - val_accuracy: 0.2908
# Epoch 7/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0137 - accuracy: 0.2327 - val_loss: 2.0307 - val_accuracy: 0.1924
# Epoch 8/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0108 - accuracy: 0.2109 - val_loss: 2.0620 - val_accuracy: 0.2103
# Epoch 9/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0218 - accuracy: 0.2059 - val_loss: 2.0203 - val_accuracy: 0.1924
# Epoch 10/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0176 - accuracy: 0.2115 - val_loss: 2.0334 - val_accuracy: 0.2058
# Epoch 11/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0203 - accuracy: 0.2076 - val_loss: 2.0204 - val_accuracy: 0.2058
# Epoch 12/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0182 - accuracy: 0.2048 - val_loss: 2.0218 - val_accuracy: 0.1924
# Epoch 13/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0167 - accuracy: 0.1936 - val_loss: 2.0217 - val_accuracy: 0.2058
# Epoch 14/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0271 - accuracy: 0.2048 - val_loss: 2.0266 - val_accuracy: 0.2036
# Epoch 15/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0161 - accuracy: 0.2048 - val_loss: 2.0229 - val_accuracy: 0.2058
# Epoch 16/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0170 - accuracy: 0.1998 - val_loss: 2.0232 - val_accuracy: 0.2058
# Epoch 17/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0145 - accuracy: 0.1959 - val_loss: 2.0250 - val_accuracy: 0.2058
# Epoch 18/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0157 - accuracy: 0.2093 - val_loss: 2.0230 - val_accuracy: 0.1924
# Epoch 19/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0143 - accuracy: 0.1998 - val_loss: 2.0217 - val_accuracy: 0.2058
# Epoch 20/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0158 - accuracy: 0.2009 - val_loss: 2.0321 - val_accuracy: 0.2058
# Epoch 21/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0148 - accuracy: 0.1981 - val_loss: 2.0289 - val_accuracy: 0.2058
# Epoch 22/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0120 - accuracy: 0.2048 - val_loss: 2.0627 - val_accuracy: 0.2304
# Epoch 23/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0298 - accuracy: 0.2098 - val_loss: 2.0245 - val_accuracy: 0.2058
# Epoch 24/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0218 - accuracy: 0.2059 - val_loss: 2.0238 - val_accuracy: 0.1924
# Epoch 25/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0195 - accuracy: 0.1959 - val_loss: 2.0224 - val_accuracy: 0.2058
# Epoch 26/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0156 - accuracy: 0.2042 - val_loss: 2.0267 - val_accuracy: 0.2036
# Epoch 27/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0140 - accuracy: 0.1964 - val_loss: 2.0237 - val_accuracy: 0.2058
# Epoch 28/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0151 - accuracy: 0.2070 - val_loss: 2.0219 - val_accuracy: 0.2058
# Epoch 29/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0143 - accuracy: 0.2081 - val_loss: 2.0254 - val_accuracy: 0.2058
# Epoch 30/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0135 - accuracy: 0.2081 - val_loss: 2.0259 - val_accuracy: 0.2036

# %% [markdown]
# **Visualizing the results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Finding from Second Model
#
#
# There is improvement in accuracy and can see the overfitting problem has solved due to data augmentation

# %% [markdown]
# Todo: Find the distribution of classes in the training dataset.
#
# Context: Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 1     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 2     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 3     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 4     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2235  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2236  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2237  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2238  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 1     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 2     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 3     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 4     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2235  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2236  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2237  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2238  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# Which class has the least number of samples?
#
# Seborrheic keratosis has least number of samples

# %% [markdown]
# Which classes dominate the data in terms proportionate number of samples?
#
# Pigmented benign keratosis, Melonoma, Basal cell carcinoma and Nevus have proprtionate number of classes

# %% [markdown]
# Todo: Rectify the class imbalance
#
# Context: You can use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use Augmentor, the following general procedure is followed:
#
# Instantiate a Pipeline object pointing to a directory containing your initial image data set.
# Define a number of operations to perform on this data set using your Pipeline object.
# Execute these operations by calling the Pipeline’s sample() method.

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %%
path_to_training_dataset="/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train",save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FB37A513AD0>: 100%|██████████| 500/500 [00:44<00:00, 11.34 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FB37F316F10>: 100%|██████████| 500/500 [00:40<00:00, 12.35 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FB37A5D2B10>: 100%|██████████| 500/500 [00:40<00:00, 12.36 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FB37F3CB9D0>: 100%|██████████| 500/500 [00:39<00:00, 12.71 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7FB37A5D2E10>: 100%|██████████| 500/500 [00:46<00:00, 10.77 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FB37EA48C10>: 100%|██████████| 500/500 [00:48<00:00, 10.37 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FB37A51F2D0>: 100%|██████████| 500/500 [00:47<00:00, 10.46 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FB37A4CC3D0>: 100%|██████████| 500/500 [00:48<00:00, 10.32 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7FB37F2F0250>: 100%|██████████| 500/500 [00:47<00:00, 10.58 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train1 = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %%
for i in class_names:
      
    for j in data_dir_train1.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
new_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 1     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 2     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 3     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 4     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# ...                                                 ...                ...
# 6734  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 6735  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 6736  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 6737  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 6738  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
#
# [6739 rows x 2 columns]

# %% [markdown]
# **Lets see the distribution of augmented data after adding new images to the original training data.**

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    1394
# melanoma                      1333
# basal cell carcinoma          1148
# nevus                         1070
# squamous cell carcinoma        530
# vascular lesion                438
# actinic keratosis              333
# dermatofibroma                 264
# seborrheic keratosis           229
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# Todo: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Todo: Create a training dataset

# %%
data_dir_train1 = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# Create model (make sure to include normalization)

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ 
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# Compile model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Train model

# %%
epochs =50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 113/113 [==============================] - 23s 191ms/step - loss: 2.0424 - accuracy: 0.2017 - val_loss: 2.0294 - val_accuracy: 0.2033
# Epoch 2/50
# 113/113 [==============================] - 20s 170ms/step - loss: 2.0092 - accuracy: 0.2044 - val_loss: 1.9993 - val_accuracy: 0.2111
# Epoch 3/50
# 113/113 [==============================] - 20s 172ms/step - loss: 2.0053 - accuracy: 0.2275 - val_loss: 1.9817 - val_accuracy: 0.2244
# Epoch 4/50
# 113/113 [==============================] - 20s 168ms/step - loss: 1.9196 - accuracy: 0.2897 - val_loss: 1.7870 - val_accuracy: 0.4056
# Epoch 5/50
# 113/113 [==============================] - 21s 174ms/step - loss: 1.7316 - accuracy: 0.3758 - val_loss: 1.5106 - val_accuracy: 0.4567
# Epoch 6/50
# 113/113 [==============================] - 20s 169ms/step - loss: 1.4807 - accuracy: 0.4731 - val_loss: 1.3631 - val_accuracy: 0.5367
# Epoch 7/50
# 113/113 [==============================] - 20s 168ms/step - loss: 1.3829 - accuracy: 0.5069 - val_loss: 1.2841 - val_accuracy: 0.5567
# Epoch 8/50
# 113/113 [==============================] - 20s 167ms/step - loss: 1.2635 - accuracy: 0.5522 - val_loss: 1.3044 - val_accuracy: 0.5178
# Epoch 9/50
# 113/113 [==============================] - 21s 181ms/step - loss: 1.1762 - accuracy: 0.5833 - val_loss: 1.1533 - val_accuracy: 0.6056
# Epoch 10/50
# 113/113 [==============================] - 20s 168ms/step - loss: 1.0967 - accuracy: 0.6158 - val_loss: 1.2597 - val_accuracy: 0.5733
# Epoch 11/50
# 113/113 [==============================] - 20s 169ms/step - loss: 1.0081 - accuracy: 0.6392 - val_loss: 1.1228 - val_accuracy: 0.5989
# Epoch 12/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.9260 - accuracy: 0.6694 - val_loss: 1.2942 - val_accuracy: 0.5278
# Epoch 13/50
# 113/113 [==============================] - 20s 170ms/step - loss: 0.8613 - accuracy: 0.6914 - val_loss: 1.2111 - val_accuracy: 0.5922
# Epoch 14/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.8256 - accuracy: 0.7011 - val_loss: 1.1245 - val_accuracy: 0.6078
# Epoch 15/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.7164 - accuracy: 0.7444 - val_loss: 1.1186 - val_accuracy: 0.6333
# Epoch 16/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.6568 - accuracy: 0.7658 - val_loss: 1.0673 - val_accuracy: 0.6633
# Epoch 17/50
# 113/113 [==============================] - 21s 181ms/step - loss: 0.6118 - accuracy: 0.7772 - val_loss: 1.2406 - val_accuracy: 0.6478
# Epoch 18/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.5652 - accuracy: 0.8006 - val_loss: 1.2672 - val_accuracy: 0.6467
# Epoch 19/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.5410 - accuracy: 0.8072 - val_loss: 1.2238 - val_accuracy: 0.6578
# Epoch 20/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.4727 - accuracy: 0.8308 - val_loss: 1.3553 - val_accuracy: 0.6389
# Epoch 21/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.4682 - accuracy: 0.8389 - val_loss: 1.1603 - val_accuracy: 0.7044
# Epoch 22/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.3750 - accuracy: 0.8625 - val_loss: 1.3974 - val_accuracy: 0.6911
# Epoch 23/50
# 113/113 [==============================] - 20s 170ms/step - loss: 0.3749 - accuracy: 0.8664 - val_loss: 1.2831 - val_accuracy: 0.6889
# Epoch 24/50
# 113/113 [==============================] - 20s 170ms/step - loss: 0.3882 - accuracy: 0.8717 - val_loss: 1.4766 - val_accuracy: 0.6833
# Epoch 25/50
# 113/113 [==============================] - 20s 171ms/step - loss: 0.3646 - accuracy: 0.8717 - val_loss: 1.3255 - val_accuracy: 0.6967
# Epoch 26/50
# 113/113 [==============================] - 21s 170ms/step - loss: 0.3001 - accuracy: 0.8994 - val_loss: 1.4787 - val_accuracy: 0.6878
# Epoch 27/50
# 113/113 [==============================] - 20s 172ms/step - loss: 0.2669 - accuracy: 0.9119 - val_loss: 1.5713 - val_accuracy: 0.6967
# Epoch 28/50
# 113/113 [==============================] - 20s 170ms/step - loss: 0.2505 - accuracy: 0.9139 - val_loss: 1.5817 - val_accuracy: 0.7211
# Epoch 29/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.3017 - accuracy: 0.8956 - val_loss: 1.3973 - val_accuracy: 0.7244
# Epoch 30/50
# 113/113 [==============================] - 20s 170ms/step - loss: 0.3045 - accuracy: 0.9011 - val_loss: 1.5677 - val_accuracy: 0.7233
# Epoch 31/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.2172 - accuracy: 0.9269 - val_loss: 1.5817 - val_accuracy: 0.7078
# Epoch 32/50
# 113/113 [==============================] - 20s 171ms/step - loss: 0.2075 - accuracy: 0.9275 - val_loss: 1.7481 - val_accuracy: 0.7044
# Epoch 33/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1945 - accuracy: 0.9378 - val_loss: 1.7341 - val_accuracy: 0.7289
# Epoch 34/50
# 113/113 [==============================] - 21s 180ms/step - loss: 0.1853 - accuracy: 0.9372 - val_loss: 2.2365 - val_accuracy: 0.7000
# Epoch 35/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1806 - accuracy: 0.9369 - val_loss: 1.7691 - val_accuracy: 0.7422
# Epoch 36/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.2110 - accuracy: 0.9247 - val_loss: 1.6440 - val_accuracy: 0.7478
# Epoch 37/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1788 - accuracy: 0.9417 - val_loss: 1.7286 - val_accuracy: 0.7367
# Epoch 38/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1479 - accuracy: 0.9547 - val_loss: 1.5662 - val_accuracy: 0.7589
# Epoch 39/50
# 113/113 [==============================] - 21s 181ms/step - loss: 0.1706 - accuracy: 0.9411 - val_loss: 1.7989 - val_accuracy: 0.7400
# Epoch 40/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1589 - accuracy: 0.9514 - val_loss: 1.5339 - val_accuracy: 0.7056
# Epoch 41/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1685 - accuracy: 0.9433 - val_loss: 1.8125 - val_accuracy: 0.7389
# Epoch 42/50
# 113/113 [==============================] - 21s 179ms/step - loss: 0.2158 - accuracy: 0.9328 - val_loss: 1.8299 - val_accuracy: 0.7444
# Epoch 43/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1517 - accuracy: 0.9508 - val_loss: 1.7166 - val_accuracy: 0.7067
# Epoch 44/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1721 - accuracy: 0.9450 - val_loss: 1.7051 - val_accuracy: 0.7544
# Epoch 45/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1286 - accuracy: 0.9589 - val_loss: 2.0345 - val_accuracy: 0.7256
# Epoch 46/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1281 - accuracy: 0.9586 - val_loss: 1.9529 - val_accuracy: 0.7511
# Epoch 47/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1417 - accuracy: 0.9567 - val_loss: 2.0408 - val_accuracy: 0.7367
# Epoch 48/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1307 - accuracy: 0.9600 - val_loss: 1.6929 - val_accuracy: 0.7522
# Epoch 49/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1085 - accuracy: 0.9633 - val_loss: 1.8376 - val_accuracy: 0.7467
# Epoch 50/50
# 113/113 [==============================] - 20s 166ms/step - loss: 0.1443 - accuracy: 0.9592 - val_loss: 1.6652 - val_accuracy: 0.7444

# %% [markdown]
# Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# Ans: Accuracy on training data has increased by using Augmentor library
#
# Model is still overfitting
